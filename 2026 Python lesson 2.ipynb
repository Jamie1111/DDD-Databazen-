# %% [markdown]
# # Iteration 1 DDD Databazen🤓

# %% [markdown]
# ## 1 Loading Data

# %% [markdown]
# De dataset staat in de data map

# %% [markdown]
# We installeren hier pandas zodat we met deze library kunnen werken de import pandas as pd zorgt er voor dat we pandas kunnen aanroepen als pd

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# Dit zorgt ervoor dat we het csv bestand kunnen uitlezen en kunnen gebruiken

# %%
df = pd.read_csv('Data/ships_inventory_iter1.csv')

# %% [markdown]
# Dit laat alle unieke cellen zien van de sector kolom

# %%
df['Sector'].unique()
# Out:
# array(['Mon Cala Ocean Worlds', 'Thraxos Blockade', 'Indoumodo Sector',
#        'Pantora Moon', 'Malastare Narrows', 'Calodan Expanse',
#        'Mimban Swamp', 'Iridonia Belt', 'Wroona Spaceport',
#        'Ilum Crystal Regions', 'Crait Outpost', 'Alderaan System',
#        'Mandalore Sector', 'Sector NAN-Alpha', 'Akiva Territory',
#        'Florrum Badlands', 'Nal Hutta Space', 'New Yavin',
#        'Wookiee Aligned Systems', 'Onderon Wilds', 'Nar Shaddaa Moon',
#        'Ord Ibanna Clouds', 'Iago Cluster', 'Wyl Sector',
#        'Nova Corps Base', 'Tatooine Binary System', 'Azimuth Prime',
#        'Mustafar Mining Zone', 'Scarif Shield Gate', 'Vardos City',
#        'Gamorr Nebula', 'Moraband Wastes', 'Lothal Outer Rim',
#        'Mygeeto Banking Clan', 'Kyber Deep', 'Naboo Royal Sector',
#        'Njedha Holy City', 'Mustafar Border', 'Kashyyyk Homeworld',
#        'Coruscant Core', 'Hoth System', 'Ord Mantell Junkyard',
# ...

# %% [markdown]
# ### Histogram

# %% [markdown]
# Hier installeren we een library voor het maken van histogrammen

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.1.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp314-cp314-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Using cached pillow-12.1.0-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Dit is de code van het histogram

# %%
plt.hist(x=df['Year_of_Release'])
plt.title('This is the title of the plot')
plt.show()
